# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
import cv2
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a3d8a6fb-5a93-46bf-8d86-f1fbd7b1acb6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3d8a6fb-5a93-46bf-8d86-f1fbd7b1acb6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 02Rice.png to 02Rice.png

# %%
IMAGE = cv2.imread("02Rice.png",0)
fig, aux = plt.subplots(figsize=(8,8))
aux.imshow(IMAGE,cmap="gray")

# %%
LAPLACIAN = cv2.Laplacian(IMAGE, cv2.CV_64F, ksize=5)
fig, aux = plt.subplots(figsize=(8,8))
aux.imshow(LAPLACIAN,cmap="gray")

# %%
SOBELX = cv2.Sobel(IMAGE, cv2.CV_64F, 1, 0, ksize =5)

fig, aux = plt.subplots(figsize = (8,8))
aux.imshow(SOBELX, cmap="gray")

# %%
SOBELY = cv2.Sobel(IMAGE, cv2.CV_64F, 0, 1, ksize =5)

fig, aux = plt.subplots(figsize = (8,8))
aux.imshow(SOBELY, cmap="gray")

# %%
CANNY = cv2.Canny(IMAGE, 50, 200)

fig, aux = plt.subplots(figsize = (8,8))
aux.imshow(CANNY, cmap="gray")
